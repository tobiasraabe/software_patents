# %%
import sys
sys.path.append('../..')

import pandas as pd

from bld.project_paths import project_paths_join as ppj

# %%
df = pd.read_table(ppj('IN_DATA_RAW', 'detail_desc_text_1.tsv.zip'), sep='\t',
                   nrows=10, skiprows=1000000, usecols=[1, 2],
                   names=['ID', 'DESCRIPTION'])
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-d6346cabcfb2> in <module>()
#       1 df = pd.read_table(ppj('IN_DATA_RAW', 'detail_desc_text_1.tsv.zip'), sep='\t',
#       2                    nrows=10, skiprows=1000000, usecols=[1, 2],
# ----> 3                    names=['ID', 'DESCRIPTION'])
#
# ...

# %%
df
# Out:
#    5qvd6eebjsw4v789szbp7gu4k  7973541  \
# 0  5qvd8d4d3xznh6dis3wx3yjza  9003505
# 1  5qvdkkrmm8roq2l3mufvlztqx  5360706
# 2  5qvdqgyzau434pbct14npe0p9  8175726
# 3  5qve28gpmibuahp57psv85nw6  6717590
# 4  5qve6cfj6rwchsbespn4p80u6  9778943
# 5  5qvedka7nvgkmmvtl85c6shuh  8416072
# 6  5qvekptl6sw7n8n5ohyjtotm9  6353603
# 7  5qvemo78qyancbsi64ka9lacg  5727634
# 8  5qveqd2s690lzn1hhxbuqi5s9  7699460
# 9  5qvf1s0hf5hhocvm1yp9bnpxt  8109750
#
# ...

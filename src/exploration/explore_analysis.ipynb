# %%
# %matplotlib inline
import sys
sys.path.append('../..')
import pandas as pd
from bld.project_paths import project_paths_join as ppj
from sklearn.metrics import confusion_matrix

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold

# %%
# df = pd.read_pickle(ppj('OUT_ANALYSIS', 'replication_bh.pkl'))
df = pd.read_pickle(ppj('OUT_DATA', 'bh_bool.pkl'))

# %%
df.drop(columns='CLASSIFICATION_ALGORITHM', inplace=True)

# %%
param_dist = {
    'clf__penalty': ['l1', 'l2'],
    'clf__max_iter': [1000, 2000],
    'clf__C': np.arange(0.001, 0.101, 0.001),
    'clf__fit_intercept': [True, False],
}

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

random_search = RandomizedSearchCV(
    classifier, param_distributions=param_dist,
    n_iter=RANDOM_SEARCH_N_ITER, scoring=ap_scorer, n_jobs=cpu_num, cv=skf,
    return_train_score=True, random_state=RANDOM_STATE)

# %%
df
# Out:
#     CLASSIFICATION_MANUAL       ID  TITLE_SOFTWARE  ABSTRACT_SOFTWARE  \
# 0            Non-Software  5480963           False              False
# 1            Non-Software  5482462           False              False
# 2                Software  5483884           False              False
# 3            Non-Software  5484069           False              False
# 4            Non-Software  5487794           False              False
# 5            Non-Software  5487917           False              False
# 6            Non-Software  5488237           False              False
# 7            Non-Software  5489185           False              False
# 8            Non-Software  5489429           False              False
# 9            Non-Software  5489660           False              False
# 10           Non-Software  5492504           False              False
# 11               Software  5493364           False              False
# ...
